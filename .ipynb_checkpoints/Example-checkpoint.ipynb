# %% [markdown]
# # first print

# %%
print("First Print in Python")
# Out:
# First Print in Python

# %%
# print my name 
print ("Saad Rimeh")
# Out:
# Saad Rimeh

# %% [markdown]
# # Data Type

# %%
type(2)
# Out:
# int

# %%
type(2.5)
# Out:
# float

# %%
type('s')
# Out:
# str

# %%
type("saad")
# Out:
# str

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %% [markdown]
# ## OP

# %%
1+2
# Out:
# 3

# %%
2.4+2
# Out:
# 4.4

# %%
2*2
# Out:
# 4

# %%
2/2
# Out:
# 1.0

# %%
2%2
# Out:
# 0

# %% [markdown]
# # String Method

# %%
"saad rimeh".upper()
# Out:
# 'SAAD RIMEH'

# %%
"Saad Rimeh".lower()
# Out:
# 'saad rimeh'

# %%
"title".title()
# Out:
# 'Title'

# %%
# here will print the last method in the cell but if we have a print they will run all of it
"saad rimeh".upper()
"Saad Rimeh".lower()
"title".title()
# Out:
# 'Title'

# %%
# count how many a in the string
"saad rimeh".count('a')
# Out:
# 2

# %%
# A != a
"saad rimeh".count('A')
# Out:
# 0

# %%
# replace a with A
"saad rimeh".replace('a','A')
# Out:
# 'sAAd rimeh'

# %% [markdown]
# # Variables

# %%
# A variable is a named container in a program's memory used to store data that can be referenced, used, or changed later.

# %%
message_1 = "I am learning Python "

# %%
# To output the value of a variable, simply pass its name to the print function
message_1
# Out:
# 'I am learning Python '

# %%
message_2 = "and it is fun!"

# %%
message_2
# Out:
# 'and it is fun!'

# %%
message_1
# Out:
# 'I am learning Python'

# %%
# it will run onle the last line
message_1
message_2
# Out:
# 'and it is fun!'

# %%
message_1 + message_2
# Out:
# 'I am learning Pythonand it is fun!'

# %%
message_1 + message_2
# Out:
# 'I am learning Python and it is fun!'

# %%
# if we not put space in the last of message_1 the output will be I am learning Pythonand it is fun!
# we can write like this message_1 + " " + message_2 but it not professional

# %%
message = message_1 + message_2
message
# Out:
# 'I am learning Python and it is fun!'

# %%
f'Hello World'
# Out:
# 'Hello World'

# %%
f'{message_1}{message_2}'
# Out:
# 'I am learning Python and it is fun!'

# %%
# if we but abs btween {}{} the output will be I am learning Python abcand it is fun!
f'{message_1}abc{message_2}'
# Out:
# 'I am learning Python abcand it is fun!'

# %% [markdown]
# # List

# %%
# A list is an ordered and changeable data structure used to store a collection of multiple items within a single variable.

# %%
countries=['Japan' , 'Brazil' , 'Canada' , 'Australia' , 'Egypt']

# %%
countries
# Out:
# ['Japan', 'Brazil', 'Canada', 'Australia', 'Egypt']

# %%
# List mabye contain more than one data type

# %%
# Access a specific element by its index, keeping in mind that the first index is always 0

# %%
countries [0]
# Out:
# 'Japan'

# %%
countries [1]
# Out:
# 'Brazil'

# %%
countries [2]
# Out:
# 'Canada'

# %%
countries [3]
# Out:
# 'Australia'

# %%
countries [4]
# Out:
# 'Egypt'

# %%
# the length of the countries list is 4 if we write countries [5] the output will be IndexError: list index out of range

# %%
# Use negative indexing to access elements from the end of the list, where -1 refers to the last item

# %%
countries [-1]
# Out:
# 'Egypt'

# %%
countries [-2]
# Out:
# 'Australia'

# %%
countries [-3]
# Out:
# 'Canada'

# %%
countries [-4]
# Out:
# 'Brazil'

# %%
# Use slicing to extract a portion of a list by specifying a start and stop index [start:stop]

# %%
# it stope on number 3 so it print untile 2
countries [0:3]
# Out:
# ['Japan', 'Brazil', 'Canada']

# %% [markdown]
# ## Adding elements to a list

# %%
countries
# Out:
# ['Japan', 'Brazil', 'Canada', 'Australia', 'Egypt']

# %%
# add element at the end of list
countries.append('Syria')

# %%
countries
# Out:
# ['Japan', 'Brazil', 'Canada', 'Australia', 'Egypt', 'Syria', 'Syria']

# %%
# add element at the first fo list
countries.insert(0,'spain')

# %%
countries
# Out:
# ['spain', 'Japan', 'Brazil', 'Canada', 'Australia', 'Egypt', 'Syria', 'Syria']

# %%
countries_2 = ['UK' , 'Germany']

# %%
countries + countries_2
# Out:
# ['spain',
#  'Japan',
#  'Brazil',
#  'Canada',
#  'Australia',
#  'Egypt',
#  'Syria',
#  'Syria',
#  'UK',
#  'Germany']

# %%
nested_list = [countries_2 ,countries]

# %%
nested_list
# Out:
# [['UK', 'Germany'],
#  ['spain',
#   'Japan',
#   'Brazil',
#   'Canada',
#   'Australia',
#   'Egypt',
#   'Syria',
#   'Syria']]

# %%
countries_2.insert(0,countries)

# %%
countries_2
# Out:
# [['spain',
#   'Japan',
#   'Brazil',
#   'Canada',
#   'Australia',
#   'Egypt',
#   'Syria',
#   'Syria'],
#  'UK',
#  'Germany']

# %% [markdown]
# ## Removing an elements

# %%
# remove the elment from the lsit
countries.remove("Syria")

# %%
countries
# Out:
# ['spain', 'Japan', 'Brazil', 'Canada', 'Australia', 'Egypt']

# %%
# removing with index using pop
countries.pop(-1)
# Out:
# 'Egypt'

# %%
# pop remove the element on the index and returne the elemet

# %%
del countries [0]

# %%
countries
# Out:
# ['Japan', 'Brazil', 'Canada', 'Australia']

# %%
#The key difference is that pop() removes an item and returns its value so you can use it, whereas del simply deletes the item without returning anything.

# %% [markdown]
# ## Sorting a list

# %%
numbers = [ 5 , 2 , 7 , 1 ,9 ,10 , 6 , 0 ]

# %%
# defulte from small to lage
numbers.sort()

# %%
numbers
# Out:
# [0, 1, 2, 5, 6, 7, 9, 10]

# %%
# Set reverse=True to sort the list in descending order (from highest to lowest)

# %%
numbers = [ 5 , 2 , 7 , 1 ,9 ,10 , 6 , 0 ]
numbers.sort(reverse=True)

# %%
numbers
# Out:
# [10, 9, 7, 6, 5, 2, 1, 0]
